# %%
import pandas as pd
import os
import glob
import csv

# %% [markdown]
# ### File aquiration template

# %%
# Source file cleaning
# Fill in the source number
source_number = 2
# Fill in your own file path, have the folder containing the csv files be called "Source_{number}"
# Make sure to change any \ to / to avoid errors
source_folder_path = f"C:/Users/Sverre/Documents/UNI/2amd20/Sources_compiled/Source_{source_number}/"

# Open the source folder to take all CSV's from
csv_files_Source = glob.glob(os.path.join(f"{source_folder_path}", "*.csv"))

# Open the file to store the new CSV in
compiled_file_source = open(f"{source_folder_path}/Source_{source_number}_full_converted_raw.csv", "a")
# Start the CSV writer
compiled_file_source_writer = csv.writer(compiled_file_source)

# Go through all raw source files in the provided folder
for file_path in csv_files_Source:
    raw_file = open(file_path, "r")
    # Split the input file in lines
    raw_file_lines = raw_file.readlines()
    for line in raw_file_lines:
        # Split each line on the column split symbol ";"
        raw_line_split = line.split(';')
        # Add the split row to the new file
        compiled_file_source_writer.writerow(raw_line_split)
    raw_file.close()
compiled_file_source.close()

# Pandas sanity check, open the just created file
pd.read_csv(f"{source_folder_path}/Source_{source_number}_full_converted_raw.csv")

# %% [markdown]
# ### Source 1 preprocessing

# %% [markdown]
# ### Source 2 preprocessing

# %%
# Source file cleaning
source_number = 2
source_folder_path = f"C:/Users/Sverre/Documents/UNI/2amd20/Sources_compiled/Source_{source_number}/"
# Open the source folder to take all CSV's from
csv_files_Source = glob.glob(os.path.join(f"{source_folder_path}", "*.csv"))

# Open the file to store the new CSV in
compiled_file_source = open(f"{source_folder_path}/Source_{source_number}_full_converted_raw.csv", "a")
# Start the CSV writer
compiled_file_source_writer = csv.writer(compiled_file_source)

# Go through all raw source files in the provided folder
for file_path in csv_files_Source:
    raw_file = open(file_path, "r")
    # Split the input file in lines
    raw_file_lines = raw_file.readlines()
    for line in raw_file_lines:
        # Split each line on the column split symbol ";"
        raw_line_split = line.split(';')
        # Add the split row to the new file
        compiled_file_source_writer.writerow(raw_line_split)
    raw_file.close()
compiled_file_source.close()

# %%
# Pandas sanity check, open the just created file
pd.read_csv(f"{source_folder_path}/Source_{source_number}_full_converted_raw.csv")
# Out:
#       Perioden      Regio's  \
# 0         2019  Aa en Hunze
# 1         2020  Aa en Hunze
# 2         2021  Aa en Hunze
# 3         2019      Aalburg
# 4         2020      Aalburg
# ...        ...          ...
# 2173      2020  Zwijndrecht
# 2174      2021  Zwijndrecht
# 2175      2019       Zwolle
# 2176      2020       Zwolle
# 2177      2021       Zwolle
#
#       Bevolking/Bevolkingssamenstelling op 1 januari/Totale bevolking (aantal)  \
# 0                                               25386.0
# 1                                               25445.0
# 2                                               25399.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                            44737.0
# 2174                                            44775.0
# 2175                                           127497.0
# 2176                                           128840.0
# 2177                                           129840.0
#
#       Bevolking/Bevolkingssamenstelling op 1 januari/Geslacht/Mannen (aantal)  \
# 0                                               12659.0
# 1                                               12708.0
# 2                                               12709.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                            21694.0
# 2174                                            21754.0
# 2175                                            62794.0
# 2176                                            63488.0
# 2177                                            63944.0
#
#       Bevolking/Bevolkingssamenstelling op 1 januari/Geslacht/Vrouwen (aantal)  \
# 0                                               12727.0
# 1                                               12737.0
# 2                                               12690.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                            23043.0
# 2174                                            23021.0
# 2175                                            64703.0
# 2176                                            65352.0
# 2177                                            65896.0
#
#       Bevolking/Bevolkingssamenstelling op 1 januari/Leeftijd/Leeftijdsgroepen/Jonger dan 5 jaar (aantal)  \
# 0                                                 922.0
# 1                                                 946.0
# 2                                                 937.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                             2348.0
# 2174                                             2350.0
# 2175                                             7190.0
# 2176                                             7063.0
# 2177                                             7031.0
#
#       Bevolking/Bevolkingssamenstelling op 1 januari/Leeftijd/Leeftijdsgroepen/5 tot 10 jaar (aantal)  \
# 0                                                1174.0
# 1                                                1160.0
# 2                                                1137.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                             2398.0
# 2174                                             2370.0
# 2175                                             7776.0
# 2176                                             7754.0
# 2177                                             7537.0
#
#       Bevolking/Bevolkingssamenstelling op 1 januari/Leeftijd/Leeftijdsgroepen/10 tot 15 jaar (aantal)  \
# 0                                                1366.0
# 1                                                1354.0
# 2                                                1309.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                             2452.0
# 2174                                             2520.0
# 2175                                             7708.0
# 2176                                             7833.0
# 2177                                             7851.0
#
#       Bevolking/Bevolkingssamenstelling op 1 januari/Leeftijd/Leeftijdsgroepen/15 tot 20 jaar (aantal)  \
# 0                                                1579.0
# 1                                                1545.0
# 2                                                1508.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                             2509.0
# 2174                                             2466.0
# 2175                                             7754.0
# 2176                                             7785.0
# 2177                                             7850.0
#
#       Bevolking/Bevolkingssamenstelling op 1 januari/Leeftijd/Leeftijdsgroepen/20 tot 25 jaar (aantal)  \
# 0                                                1031.0
# 1                                                1079.0
# 2                                                1103.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                             2408.0
# 2174                                             2420.0
# 2175                                             8586.0
# 2176                                             8714.0
# 2177                                             8887.0
#
#       ...  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...   ...
# 2173  ...
# 2174  ...
# 2175  ...
# 2176  ...
# 2177  ...
#
#       Onderwijs/Naar woongemeente/Gediplomeerden/Wo master/doctoraal (aantal)  \
# 0                                                   8.0
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                                NaN
# 2174                                                NaN
# 2175                                              122.0
# 2176                                                NaN
# 2177                                                NaN
#
#       Arbeid/Banen van werknemers, relatief/A Landbouw, bosbouw en visserij (%)  \
# 0                                                   1.0
# 1                                                   1.0
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                                0.0
# 2174                                                NaN
# 2175                                                0.0
# 2176                                                0.0
# 2177                                                NaN
#
#       Arbeid/Banen van werknemers, relatief/B-F Nijverheid en energie (%)  \
# 0                                                  10.0
# 1                                                   8.0
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                               20.0
# 2174                                                NaN
# 2175                                               10.0
# 2176                                               10.0
# 2177                                                NaN
#
#       Arbeid/Banen van werknemers, relatief/G-N Commerciële dienstverlening (%)  \
# 0                                                  45.0
# 1                                                  43.0
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                               55.0
# 2174                                                NaN
# 2175                                               48.0
# 2176                                               47.0
# 2177                                                NaN
#
#      Arbeid/Banen van werknemers, relatief/O-U Niet-commerciële dienstverlening (%)  \
# 0                                                  44.0
# 1                                                  47.0
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                               25.0
# 2174                                                NaN
# 2175                                               42.0
# 2176                                               42.0
# 2177                                                NaN
#
#      Nabijheid voorzieningen/Gezondheid/Afstand tot huisartsenpraktijk (km)  \
# 0                                                   2,4
# 1                                                   2,4
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                                0,7
# 2174                                                NaN
# 2175                                                  1
# 2176                                                0,9
# 2177                                                NaN
#
#      Nabijheid voorzieningen/Gezondheid/Aantal huisartsenpraktijken binnen 3 km (aantal)  \
# 0                                                   1,3
# 1                                                   1,1
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                                6,5
# 2174                                                NaN
# 2175                                                7,7
# 2176                                                7,2
# 2177                                                NaN
#
#      Nabijheid voorzieningen/Gezondheid/Afstand tot huisartsenpost (km)  \
# 0                                                  11,1
# 1                                                  11,1
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                                6,5
# 2174                                                NaN
# 2175                                                4,2
# 2176                                                4,2
# 2177                                                NaN
#
#      Nabijheid voorzieningen/Gezondheid/Afstand tot ziekenhuis (km)  \
# 0                                                  11,1
# 1                                                  11,1
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2173                                                2,5
# 2174                                                NaN
# 2175                                                4,2
# 2176                                                4,2
# 2177                                                NaN
#
#      Nabijheid voorzieningen/Gezondheid/Aantal ziekenhuizen binnen 20 km (aantal)\r\n
# 0                                               1,4\r\n
# 1                                               1,4\r\n
# 2                                                  \r\n
# 3                                                  \r\n
# 4                                                  \r\n
# ...                                                 ...
# 2173                                            8,4\r\n
# 2174                                               \r\n
# 2175                                              1\r\n
# 2176                                              1\r\n
# 2177                                               \r\n
#
# [2178 rows x 51 columns]

# %% [markdown]
# ### Source 3 preprocessing

# %% [markdown]
# ### Source 4 preprocessing

# %% [markdown]
# ### Source 5 preprocessing

# %% [markdown]
# ### Source 6 preprocessing

# %% [markdown]
# ### Source 7 preprocessing
